# %%
import pandas as pd

### Data Import ###
dfMF = pd.read_csv("./Mutual funds Performance Tracker Nov 23.csv")
dfMF
# Out:
#                                            Scheme Name         Plan  \
# 0                                     SBI Nifty 50 ETF      Regular
# 1                               SBI S&P BSE Sensex ETF      Regular
# 2    HDFC Mid-Cap Opportunities Fund - Direct Plan ...  Direct Plan
# 3             HDFC Mid-Cap Opportunities Fund - Growth      Regular
# 4    Parag Parikh Flexi Cap Fund - Direct Plan - Gr...  Direct Plan
# ..                                                 ...          ...
# 825  SBI CRISIL IBX SDL Index - September 2027 Fund...  Direct Plan
# 826  UTI CRISIL SDL Maturity April 2033 Index Fund ...  Direct Plan
# 827  SBI CRISIL IBX SDL Index - September 2027 Fund...      Regular
# 828                               Mirae Asset Gold ETF      Regular
# 829  Baroda BNP Paribas Nifty SDL December 2028 Ind...      Regular
#
#         Category Name Crisil Rank   AuM (Cr)  1W  1M   3M   6M  YTD   1Y   2Y  \
# 0    Index Funds/ETFs           4  155471.40  1%  0%   1%   8%  10%   8%   5%
# 1    Index Funds/ETFs           5   95206.91  1%  1%   1%   6%   9%   7%   5%
# 2        Mid Cap Fund           5   47846.43  2%  3%  10%  28%  34%  35%  21%
# 3        Mid Cap Fund           5   47846.43  2%  3%   9%  28%  33%  34%  20%
# 4      Flexi Cap Fund           -   44037.86  2%  4%   8%  16%  29%  26%   9%
# ..                ...         ...        ...  ..  ..  ...  ...  ...  ...  ...
# 825  Index Funds/ETFs           -       0.00  0%  1%   1%   3%   6%   7%  NaN
# 826  Index Funds/ETFs           -       0.00  0%  0%   1%   2%   6%  NaN  NaN
# 827  Index Funds/ETFs           -       0.00  0%  1%   1%   3%   6%   7%  NaN
# 828  Index Funds/ETFs           -       0.00  0%  4%   3%   1%  NaN  NaN  NaN
# 829  Index Funds/ETFs           -       0.00  0%  1%   1%   2%  NaN  NaN  NaN
#
#       3Y   5Y  10Y
# 0    17%  14%  NaN
# 1    16%  15%  14%
# 2    34%  22%  23%
# 3    33%  21%  22%
# 4    24%  23%  20%
# ..   ...  ...  ...
# 825  NaN  NaN  NaN
# 826  NaN  NaN  NaN
# 827  NaN  NaN  NaN
# 828  NaN  NaN  NaN
# 829  NaN  NaN  NaN
#
# [830 rows x 15 columns]

# %%
### Data Cleanup ###

dfMF['1W'] = dfMF['1W'].str.replace('%', '').fillna(0).astype(float)
dfMF['1M'] = dfMF['1M'].str.replace('%', '').fillna(0).astype(float)
dfMF['3M'] = dfMF['3M'].str.replace('%', '').fillna(0).astype(float)
dfMF['6M'] = dfMF['6M'].str.replace('%', '').fillna(0).astype(float)
dfMF['1Y'] = dfMF['1Y'].str.replace('%', '').fillna(0).astype(float)
dfMF['2Y'] = dfMF['2Y'].str.replace('%', '').fillna(0).astype(float)
dfMF['3Y'] = dfMF['3Y'].str.replace('%', '').fillna(0).astype(float)
dfMF['5Y'] = dfMF['5Y'].str.replace('%', '').fillna(0).astype(float)
dfMF['10Y'] = dfMF['10Y'].str.replace('%', '').fillna(0).astype(float)

# %%
dfMF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 830 entries, 0 to 829
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Scheme Name    830 non-null    object
#  1   Plan           830 non-null    object
#  2   Category Name  830 non-null    object
#  3   Crisil Rank    830 non-null    object
#  4   AuM (Cr)       830 non-null    float64
#  5   1W             830 non-null    float64
#  6   1M             830 non-null    float64
#  7   3M             830 non-null    float64
#  8   6M             830 non-null    float64
#  9   YTD            687 non-null    object
#  10  1Y             830 non-null    float64
#  11  2Y             830 non-null    float64
#  12  3Y             830 non-null    float64
#  13  5Y             830 non-null    float64
#  14  10Y            830 non-null    float64
# dtypes: float64(10), object(5)
# memory usage: 97.4+ KB

# %%
oneY = 10
dfMF = dfMF[dfMF['1Y'] > oneY]

# %%
threeY = 8
dfMF = dfMF[dfMF['1Y'] >= oneY]

# %%
### Main Page content ###
dfMF
# Out:
#                                            Scheme Name         Plan  \
# 2    HDFC Mid-Cap Opportunities Fund - Direct Plan ...  Direct Plan
# 3             HDFC Mid-Cap Opportunities Fund - Growth      Regular
# 4    Parag Parikh Flexi Cap Fund - Direct Plan - Gr...  Direct Plan
# 5                 Parag Parikh Flexi Cap Fund - Growth      Regular
# 8    ICICI Prudential Bluechip Fund - Direct Plan -...  Direct Plan
# ..                                                 ...          ...
# 792                       HDFC NIFTY100 Quality 30 ETF      Regular
# 796  HDFC NIFTY 100 Equal Weight Index Fund - Direc...  Direct Plan
# 798  HDFC NIFTY 100 Equal Weight Index Fund - Regul...      Regular
# 808                   HDFC NIFTY Growth Sectors 15 ETF      Regular
# 811                HDFC NIFTY100 Low Volatility 30 ETF      Regular
#
#         Category Name Crisil Rank  AuM (Cr)   1W   1M    3M    6M  YTD    1Y  \
# 2        Mid Cap Fund           5  47846.43  2.0  3.0  10.0  28.0  34%  35.0
# 3        Mid Cap Fund           5  47846.43  2.0  3.0   9.0  28.0  33%  34.0
# 4      Flexi Cap Fund           -  44037.86  2.0  4.0   8.0  16.0  29%  26.0
# 5      Flexi Cap Fund           -  44037.86  2.0  4.0   8.0  16.0  28%  25.0
# 8      Large Cap Fund           5  41269.16  1.0  1.0   5.0  14.0  16%  15.0
# ..                ...         ...       ...  ...  ...   ...   ...  ...   ...
# 792  Index Funds/ETFs           -      0.00  1.0  1.0   4.0  11.0  17%  14.0
# 796  Index Funds/ETFs           -      0.00  1.0  1.0   5.0  14.0  14%  12.0
# 798  Index Funds/ETFs           -      0.00  1.0  1.0   5.0  14.0  14%  11.0
# 808  Index Funds/ETFs           -      0.00  1.0  0.0   3.0  10.0  16%  13.0
# 811  Index Funds/ETFs           -      0.00  1.0  2.0   3.0  12.0  17%  15.0
#
#        2Y    3Y    5Y   10Y
# 2    21.0  34.0  22.0  23.0
# 3    20.0  33.0  21.0  22.0
# 4     9.0  24.0  23.0  20.0
# 5     8.0  23.0  22.0  19.0
# 8    10.0  21.0  16.0  16.0
# ..    ...   ...   ...   ...
# 792   0.0   0.0   0.0   0.0
# 796   0.0   0.0   0.0   0.0
# 798   0.0   0.0   0.0   0.0
# 808   0.0   0.0   0.0   0.0
# 811   0.0   0.0   0.0   0.0
#
# [439 rows x 15 columns]

# %%
plan_radio = "Regular"
dfMF = dfMF[dfMF['Plan'] == plan_radio]

# %%
dfMF['AuM (Cr)'].mean().round(2)
# Out:
# 4265.1

# %%
dfMF[['Scheme Name','Crisil Rank','AuM (Cr)','3M','6M','1Y','2Y','3Y','5Y','10Y']]
# Out:
#                                            Scheme Name Crisil Rank  AuM (Cr)  \
# 3             HDFC Mid-Cap Opportunities Fund - Growth           5 47,846.43
# 5                 Parag Parikh Flexi Cap Fund - Growth           - 44,037.86
# 9              ICICI Prudential Bluechip Fund - Growth           5 41,269.16
# 11                        HDFC Flexi Cap Fund - Growth           5 39,395.62
# 13                       Kotak Flexi Cap Fund - Growth           3 39,269.21
# ..                                                 ...         ...       ...
# 786          ICICI Prudential Nifty Infrastructure ETF           -      0.00
# 792                       HDFC NIFTY100 Quality 30 ETF           -      0.00
# 798  HDFC NIFTY 100 Equal Weight Index Fund - Regul...           -      0.00
# 808                   HDFC NIFTY Growth Sectors 15 ETF           -      0.00
# 811                HDFC NIFTY100 Low Volatility 30 ETF           -      0.00
#
#       3M    6M    1Y    2Y    3Y    5Y   10Y
# 3   9.00 28.00 34.00 20.00 33.00 21.00 22.00
# 5   8.00 16.00 25.00  8.00 23.00 22.00 19.00
# 9   4.00 14.00 15.00  9.00 20.00 15.00 15.00
# 11  4.00 14.00 17.00 15.00 29.00 17.00 17.00
# 13  4.00 11.00 12.00  7.00 17.00 14.00 17.00
# ..   ...   ...   ...   ...   ...   ...   ...
# 786 7.00 18.00 21.00  0.00  0.00  0.00  0.00
# 792 4.00 11.00 14.00  0.00  0.00  0.00  0.00
# 798 5.00 14.00 11.00  0.00  0.00  0.00  0.00
# 808 3.00 10.00 13.00  0.00  0.00  0.00  0.00
# 811 3.00 12.00 15.00  0.00  0.00  0.00  0.00
#
# [255 rows x 10 columns]

# %%
mfCategory = ['Small Cap Fund', 'Mid Cap Fund']
dfMF = dfMF[dfMF['Category Name'].isin(mfCategory)]

# %%
dfMF
# Out:
#                                            Scheme Name     Plan  \
# 3             HDFC Mid-Cap Opportunities Fund - Growth  Regular
# 17                Nippon India Small Cap Fund - Growth  Regular
# 21                 Kotak Emerging Equity Fund - Growth  Regular
# 33                        HDFC Small Cap Fund - Growth  Regular
# 37                           Axis Midcap Fund - Growth  Regular
# 39          SBI Small Cap Fund - Regular Plan - Growth  Regular
# 41                   Nippon India Growth Fund - Growth  Regular
# 51                        Axis Small Cap Fund - Growth  Regular
# 58             DSP Midcap Fund - Regular Plan - Growth  Regular
# 60      SBI Magnum Midcap Fund - Regular Plan - Growth  Regular
# 64                       Kotak Small Cap Fund - Growth  Regular
# 73          DSP Small Cap Fund - Regular Plan - Growth  Regular
# 75     Mirae Asset Midcap Fund - Regular Plan - Growth  Regular
# 77                        HSBC Small Cap Fund - Growth  Regular
# 89      Franklin India Smaller Companies Fund - Growth  Regular
# 93                       Quant Small Cap Fund - Growth  Regular
# 95       PGIM India Midcap Opportunities Fund - Growth  Regular
# 103                          UTI Mid Cap Fund - Growth  Regular
# 106                 Franklin India Prima Fund - Growth  Regular
# 108                     Sundaram Mid Cap Fund - Growth  Regular
# 113          HSBC Mid Cap Fund - Regular Plan - Growth  Regular
# 115  Canara Robeco Small Cap Fund - Regular Plan - ...  Regular
# 121        Tata Small Cap Fund - Regular Plan - Growth  Regular
# 123                 Motilal Oswal Midcap Fund - Growth  Regular
# 126  ICICI Prudential Smallcap Fund - Regular Plan ...  Regular
# 146  Aditya Birla Sun Life Small cap Fund - Regular...  Regular
# 148              ICICI Prudential MidCap Fund - Growth  Regular
# 150  Aditya Birla Sun Life Midcap Fund - Regular Pl...  Regular
# 158     Edelweiss Mid Cap Fund - Regular Plan - Growth  Regular
# 166                Invesco India Mid Cap Fund - Growth  Regular
# 168                        Quant Mid Cap Fund - Growth  Regular
# 172         UTI Small Cap Fund - Regular Plan - Growth  Regular
# 185               Invesco India Smallcap Fund - Growth  Regular
# 196                   Sundaram Small Cap Fund - Growth  Regular
# 200   Tata Mid Cap Growth Fund - Regular Plan - Growth  Regular
# 204   Edelweiss Small Cap Fund - Regular Plan - Growth  Regular
# 220  Bandhan Emerging Businesses Fund - Regular Pla...  Regular
# 245  PGIM India Small Cap Fund - Regular Plan - Growth  Regular
# 247         ITI Small Cap Fund - Regular Plan - Growth  Regular
# 255  Mahindra Manulife Mid Cap Fund - Regular Plan ...  Regular
# 262  Baroda BNP Paribas Mid Cap Fund - Regular Plan...  Regular
# 280       Union Small Cap Fund - Regular Plan - Growth  Regular
# 290  WhiteOak Capital Mid Cap Fund - Regular Plan -...  Regular
# 310        Bandhan Midcap Fund - Regular Plan - Growth  Regular
# 321          Union Midcap Fund - Regular Plan - Growth  Regular
# 334  Bank of India Small Cap Fund - Regular Plan - ...  Regular
# 370           ITI Mid Cap Fund - Regular Plan - Growth  Regular
# 460                       LIC MF Mid cap Fund - Growth  Regular
# 477                     LIC MF Small Cap Fund - Growth  Regular
# 515            Taurus Discovery (Midcap) Fund - Growth  Regular
# 719  ICICI Prudential Smallcap Index Fund - Regular...  Regular
# 721  PGIM India Small Cap Fund - Regular Plan - Growth  Regular
# 729    ICICI Prudential Midcap 150 Index Fund - Growth  Regular
#
#       Category Name Crisil Rank  AuM (Cr)   1W   1M    3M    6M  YTD    1Y  \
# 3      Mid Cap Fund           5 47,846.43 2.00 3.00  9.00 28.00  33% 34.00
# 17   Small Cap Fund           5 37,319.33 2.00 2.00  9.00 28.00  36% 37.00
# 21     Mid Cap Fund           3 33,699.92 1.00 2.00  7.00 20.00  23% 22.00
# 33   Small Cap Fund           4 23,183.60 2.00 1.00  8.00 24.00  35% 38.00
# 37     Mid Cap Fund           2 21,962.26 1.00 1.00  5.00 15.00  20% 17.00
# 39   Small Cap Fund           2 21,140.15 1.00 0.00  5.00 16.00  19% 19.00
# 41     Mid Cap Fund           4 19,081.97 2.00 4.00 11.00 27.00  33% 33.00
# 51   Small Cap Fund           3 16,369.16 2.00 3.00 10.00 22.00  27% 27.00
# 58     Mid Cap Fund           1 14,463.65 2.00 2.00  8.00 23.00  25% 23.00
# 60     Mid Cap Fund           4 13,202.34 1.00 1.00  8.00 17.00  25% 23.00
# 64   Small Cap Fund           3 12,162.88 1.00 1.00  5.00 19.00  24% 22.00
# 73   Small Cap Fund           3 11,837.10 2.00 1.00  8.00 27.00  31% 32.00
# 75     Mid Cap Fund           4 11,783.59 2.00 0.00  6.00 23.00  22% 21.00
# 77   Small Cap Fund           4 11,551.58 2.00 3.00 12.00 27.00  37% 37.00
# 89   Small Cap Fund           5  9,683.62 3.00 4.00 13.00 29.00  40% 42.00
# 93   Small Cap Fund           3  9,520.77 3.00 2.00  8.00 25.00  31% 36.00
# 95     Mid Cap Fund           1  9,101.52 1.00 1.00  5.00 13.00  13% 11.00
# 103    Mid Cap Fund           3  8,735.47 1.00 1.00  5.00 20.00  22% 20.00
# 106    Mid Cap Fund           2  8,499.43 2.00 2.00  8.00 21.00  24% 23.00
# 108    Mid Cap Fund           3  8,477.71 2.00 3.00 10.00 25.00  28% 26.00
# 113    Mid Cap Fund           3  8,007.73 2.00 4.00 11.00 26.00  28% 28.00
# 115  Small Cap Fund           2  7,862.59 2.00 2.00  8.00 21.00  23% 24.00
# 121  Small Cap Fund           4  6,146.73 2.00 1.00  8.00 21.00  26% 29.00
# 123    Mid Cap Fund           5  6,059.92 1.00 3.00 10.00 24.00  29% 28.00
# 126  Small Cap Fund           4  6,002.84 2.00 1.00  7.00 22.00  27% 27.00
# 146  Small Cap Fund           1  4,579.81 2.00 2.00  8.00 25.00  31% 31.00
# 148    Mid Cap Fund           2  4,252.41 2.00 2.00  8.00 19.00  18% 17.00
# 150    Mid Cap Fund           3  4,252.01 2.00 1.00  8.00 22.00  27% 23.00
# 158    Mid Cap Fund           3  3,792.81 3.00 4.00 10.00 22.00  27% 24.00
# 166    Mid Cap Fund           2  3,418.23 1.00 2.00  8.00 20.00  24% 23.00
# 168    Mid Cap Fund           4  3,267.99 1.00 1.00 10.00 27.00  23% 25.00
# 172  Small Cap Fund           -  3,139.10 2.00 2.00  9.00 23.00  26% 25.00
# 185  Small Cap Fund           2  2,869.24 3.00 7.00 14.00 30.00  36% 36.00
# 196  Small Cap Fund           3  2,626.73 3.00 3.00 11.00 27.00  34% 34.00
# 200    Mid Cap Fund           3  2,521.49 2.00 2.00  7.00 25.00  30% 28.00
# 204  Small Cap Fund           3  2,473.18 2.00 4.00 10.00 26.00  32% 32.00
# 220  Small Cap Fund           3  2,228.49 3.00 3.00 14.00 34.00  38% 40.00
# 245  Small Cap Fund           -  1,653.75 2.00 3.00  8.00 21.00  17% 14.00
# 247  Small Cap Fund           1  1,647.13 3.00 5.00 14.00 32.00  38% 39.00
# 255    Mid Cap Fund           4  1,553.59 2.00 2.00 11.00 27.00  33% 32.00
# 262    Mid Cap Fund           3  1,470.90 1.00 2.00  7.00 21.00  23% 22.00
# 280  Small Cap Fund           3  1,138.72 2.00 3.00 12.00 33.00  38% 32.00
# 290    Mid Cap Fund           -  1,109.64 2.00 3.00  9.00 27.00  30% 29.00
# 310    Mid Cap Fund           -    862.02 1.00 2.00  8.00 21.00  25% 24.00
# 321    Mid Cap Fund           3    837.77 2.00 2.00  7.00 20.00  24% 21.00
# 334  Small Cap Fund           3    723.41 3.00 4.00 16.00 31.00  36% 35.00
# 370    Mid Cap Fund           -    522.47 2.00 3.00 10.00 24.00  26% 25.00
# 460    Mid Cap Fund           2    204.44 2.00 4.00  9.00 23.00  25% 22.00
# 477  Small Cap Fund           2    168.58 1.00 1.00 10.00 20.00  24% 21.00
# 515    Mid Cap Fund           3    100.29 1.00 1.00  6.00 24.00  26% 30.00
# 719  Small Cap Fund           -      0.00 3.00 4.00 14.00 33.00  35% 35.00
# 721  Small Cap Fund           -      0.00 2.00 3.00  8.00 21.00  17% 14.00
# 729    Mid Cap Fund           -      0.00 2.00 2.00  9.00 25.00  29% 29.00
#
#        2Y    3Y    5Y   10Y
# 3   20.00 33.00 21.00 22.00
# 17  22.00 43.00 26.00 28.00
# 21  12.00 29.00 21.00 23.00
# 33  20.00 39.00 21.00 21.00
# 37   4.00 21.00 19.00 20.00
# 39  12.00 30.00 22.00 27.00
# 41  15.00 32.00 23.00 20.00
# 51  15.00 32.00 26.00  0.00
# 58   7.00 19.00 16.00 19.00
# 60  12.00 32.00 21.00 21.00
# 64   9.00 33.00 24.00 23.00
# 73  16.00 33.00 23.00 25.00
# 75  10.00 28.00  0.00  0.00
# 77  19.00 41.00 22.00  0.00
# 89  19.00 38.00 21.00 22.00
# 93  18.00 44.00 29.00 18.00
# 95   5.00 27.00 23.00  0.00
# 103  8.00 25.00 18.00 21.00
# 106  9.00 23.00 16.00 19.00
# 108 13.00 27.00 16.00 19.00
# 113 11.00 23.00 15.00 21.00
# 115 15.00 36.00  0.00  0.00
# 121 16.00 37.00 25.00  0.00
# 123 19.00 35.00 23.00  0.00
# 126 14.00 36.00 24.00 18.00
# 146 10.00 29.00 15.00 18.00
# 148  8.00 27.00 17.00 20.00
# 150  8.00 27.00 15.00 18.00
# 158 12.00 30.00 21.00 22.00
# 166 10.00 25.00 19.00 21.00
# 168 18.00 36.00 25.00 18.00
# 172 13.00  0.00  0.00  0.00
# 185 16.00 37.00 24.00  0.00
# 196 15.00 35.00 21.00 21.00
# 200 12.00 27.00 20.00 21.00
# 204 17.00 36.00  0.00  0.00
# 220 14.00 31.00  0.00  0.00
# 245  6.00  0.00  0.00  0.00
# 247 10.00 26.00  0.00  0.00
# 255 14.00 31.00 21.00  0.00
# 262 10.00 28.00 19.00 19.00
# 280 17.00 35.00 24.00  0.00
# 290  0.00  0.00  0.00  0.00
# 310  0.00  0.00  0.00  0.00
# 321  9.00 28.00  0.00  0.00
# 334 17.00 36.00  0.00  0.00
# 370  9.00  0.00  0.00  0.00
# 460  7.00 22.00 15.00  0.00
# 477 13.00 34.00 20.00  0.00
# 515 13.00 25.00 19.00 20.00
# 719 14.00  0.00  0.00  0.00
# 721  6.00  0.00  0.00  0.00
# 729  0.00  0.00  0.00  0.00
