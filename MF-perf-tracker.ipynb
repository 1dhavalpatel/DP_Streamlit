# %%
import pandas as pd

### Data Import ###
dfMF = pd.read_csv("./Mutual funds Performance Tracker Nov 23.csv")
dfMF
# Out:
#                                            Scheme Name         Plan  \
# 0                                     SBI Nifty 50 ETF      Regular
# 1                               SBI S&P BSE Sensex ETF      Regular
# 2    HDFC Mid-Cap Opportunities Fund - Direct Plan ...  Direct Plan
# 3             HDFC Mid-Cap Opportunities Fund - Growth      Regular
# 4    Parag Parikh Flexi Cap Fund - Direct Plan - Gr...  Direct Plan
# ..                                                 ...          ...
# 907  Edelweiss Maiden Opportunities Fund - Series I...      Regular
# 908  HDFC Equity Opportunities Fund - Series II - 1...  Direct Plan
# 909  HDFC Equity Opportunities Fund - Series II - 1...      Regular
# 910  HDFC Equity Opportunities Fund - Series II - 1...  Direct Plan
# 911  HDFC Equity Opportunities Fund - Series II - 1...      Regular
#
#         Category Name  Crisil Rank   AuM (Cr)   1W      1M      3M      6M  \
# 0    Index Funds/ETFs          4.0  155471.40   1%      0%      1%      8%
# 1    Index Funds/ETFs          5.0   95206.91   1%      1%      1%      6%
# 2        Mid Cap Fund          5.0   47846.43   2%      3%     10%     28%
# 3        Mid Cap Fund          5.0   47846.43   2%      3%      9%     28%
# 4      Flexi Cap Fund          NaN   44037.86   2%      4%      8%     16%
# ..                ...          ...        ...  ...     ...     ...     ...
# 907    Multi Cap Fund          NaN     521.10    0  0.0475  0.0628  0.2359
# 908    Multi Cap Fund          NaN      69.99  NaN     NaN     NaN     NaN
# 909    Multi Cap Fund          NaN      69.99  NaN     NaN     NaN     NaN
# 910    Multi Cap Fund          NaN     238.73  NaN     NaN     NaN     NaN
# 911    Multi Cap Fund          NaN     238.73  NaN     NaN     NaN     NaN
#
#         YTD     1Y      2Y      3Y      5Y  10Y
# 0       10%     8%      5%     17%     14%  NaN
# 1        9%     7%      5%     16%     15%  14%
# 2       34%    35%     21%     34%     22%  23%
# 3       33%    34%     20%     33%     21%  22%
# 4       29%    26%      9%     24%     23%  20%
# ..      ...    ...     ...     ...     ...  ...
# 907  0.3071  0.263  0.0236  0.2032  0.2088  NaN
# 908     NaN    NaN     NaN     NaN     NaN  NaN
# 909     NaN    NaN     NaN     NaN     NaN  NaN
# 910     NaN    NaN     NaN     NaN     NaN  NaN
# 911     NaN    NaN     NaN     NaN     NaN  NaN
#
# [912 rows x 15 columns]

# %%
### Data Cleanup ###

dfMF['1W'] = dfMF['1W'].str.replace('%', '').fillna(0).astype(float)
dfMF['1M'] = dfMF['1M'].str.replace('%', '').fillna(0).astype(float)
dfMF['3M'] = dfMF['3M'].str.replace('%', '').fillna(0).astype(float)
dfMF['6M'] = dfMF['6M'].str.replace('%', '').fillna(0).astype(float)
dfMF['1Y'] = dfMF['1Y'].str.replace('%', '').fillna(0).astype(float)
dfMF['2Y'] = dfMF['2Y'].str.replace('%', '').fillna(0).astype(float)
dfMF['3Y'] = dfMF['3Y'].str.replace('%', '').fillna(0).astype(float)
dfMF['5Y'] = dfMF['5Y'].str.replace('%', '').fillna(0).astype(float)
dfMF['10Y'] = dfMF['10Y'].str.replace('%', '').fillna(0).astype(float)

# %%
dfMF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912 entries, 0 to 911
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Scheme Name    912 non-null    object
#  1   Plan           912 non-null    object
#  2   Category Name  912 non-null    object
#  3   Crisil Rank    318 non-null    float64
#  4   AuM (Cr)       912 non-null    float64
#  5   1W             912 non-null    float64
#  6   1M             912 non-null    float64
#  7   3M             912 non-null    float64
#  8   6M             912 non-null    float64
#  9   YTD            737 non-null    object
#  10  1Y             912 non-null    float64
#  11  2Y             912 non-null    float64
#  12  3Y             912 non-null    float64
#  13  5Y             912 non-null    float64
#  14  10Y            912 non-null    float64
# dtypes: float64(11), object(4)
# memory usage: 107.0+ KB

# %%
oneY = 10
dfMF = dfMF[dfMF['1Y'] > oneY]

# %%
threeY = 8
dfMF = dfMF[dfMF['1Y'] >= oneY]

# %%
### Main Page content ###
dfMF
# Out:
#                                            Scheme Name         Plan  \
# 2    HDFC Mid-Cap Opportunities Fund - Direct Plan ...  Direct Plan
# 3             HDFC Mid-Cap Opportunities Fund - Growth      Regular
# 4    Parag Parikh Flexi Cap Fund - Direct Plan - Gr...  Direct Plan
# 5                 Parag Parikh Flexi Cap Fund - Growth      Regular
# 8    ICICI Prudential Bluechip Fund - Direct Plan -...  Direct Plan
# ..                                                 ...          ...
# 792                       HDFC NIFTY100 Quality 30 ETF      Regular
# 796  HDFC NIFTY 100 Equal Weight Index Fund - Direc...  Direct Plan
# 798  HDFC NIFTY 100 Equal Weight Index Fund - Regul...      Regular
# 808                   HDFC NIFTY Growth Sectors 15 ETF      Regular
# 811                HDFC NIFTY100 Low Volatility 30 ETF      Regular
#
#         Category Name  Crisil Rank  AuM (Cr)   1W   1M    3M    6M  YTD    1Y  \
# 2        Mid Cap Fund          5.0  47846.43  2.0  3.0  10.0  28.0  34%  35.0
# 3        Mid Cap Fund          5.0  47846.43  2.0  3.0   9.0  28.0  33%  34.0
# 4      Flexi Cap Fund          NaN  44037.86  2.0  4.0   8.0  16.0  29%  26.0
# 5      Flexi Cap Fund          NaN  44037.86  2.0  4.0   8.0  16.0  28%  25.0
# 8      Large Cap Fund          5.0  41269.16  1.0  1.0   5.0  14.0  16%  15.0
# ..                ...          ...       ...  ...  ...   ...   ...  ...   ...
# 792  Index Funds/ETFs          NaN      0.00  1.0  1.0   4.0  11.0  17%  14.0
# 796  Index Funds/ETFs          NaN      0.00  1.0  1.0   5.0  14.0  14%  12.0
# 798  Index Funds/ETFs          NaN      0.00  1.0  1.0   5.0  14.0  14%  11.0
# 808  Index Funds/ETFs          NaN      0.00  1.0  0.0   3.0  10.0  16%  13.0
# 811  Index Funds/ETFs          NaN      0.00  1.0  2.0   3.0  12.0  17%  15.0
#
#        2Y    3Y    5Y   10Y
# 2    21.0  34.0  22.0  23.0
# 3    20.0  33.0  21.0  22.0
# 4     9.0  24.0  23.0  20.0
# 5     8.0  23.0  22.0  19.0
# 8    10.0  21.0  16.0  16.0
# ..    ...   ...   ...   ...
# 792   0.0   0.0   0.0   0.0
# 796   0.0   0.0   0.0   0.0
# 798   0.0   0.0   0.0   0.0
# 808   0.0   0.0   0.0   0.0
# 811   0.0   0.0   0.0   0.0
#
# [439 rows x 15 columns]

# %%
plan_radio = "Regular"
dfMF = dfMF[dfMF['Plan'] == plan_radio]

# %%
dfMF['AuM (Cr)'].mean().round(2)
# Out:
# 4265.1

# %%
dfMF[['Scheme Name','Crisil Rank','AuM (Cr)','3M','6M','1Y','2Y','3Y','5Y','10Y']]
# Out:
#                                            Scheme Name  Crisil Rank  AuM (Cr)  \
# 3             HDFC Mid-Cap Opportunities Fund - Growth          5.0  47846.43
# 5                 Parag Parikh Flexi Cap Fund - Growth          NaN  44037.86
# 9              ICICI Prudential Bluechip Fund - Growth          5.0  41269.16
# 11                        HDFC Flexi Cap Fund - Growth          5.0  39395.62
# 13                       Kotak Flexi Cap Fund - Growth          3.0  39269.21
# ..                                                 ...          ...       ...
# 786          ICICI Prudential Nifty Infrastructure ETF          NaN      0.00
# 792                       HDFC NIFTY100 Quality 30 ETF          NaN      0.00
# 798  HDFC NIFTY 100 Equal Weight Index Fund - Regul...          NaN      0.00
# 808                   HDFC NIFTY Growth Sectors 15 ETF          NaN      0.00
# 811                HDFC NIFTY100 Low Volatility 30 ETF          NaN      0.00
#
#       3M    6M    1Y    2Y    3Y    5Y   10Y
# 3    9.0  28.0  34.0  20.0  33.0  21.0  22.0
# 5    8.0  16.0  25.0   8.0  23.0  22.0  19.0
# 9    4.0  14.0  15.0   9.0  20.0  15.0  15.0
# 11   4.0  14.0  17.0  15.0  29.0  17.0  17.0
# 13   4.0  11.0  12.0   7.0  17.0  14.0  17.0
# ..   ...   ...   ...   ...   ...   ...   ...
# 786  7.0  18.0  21.0   0.0   0.0   0.0   0.0
# 792  4.0  11.0  14.0   0.0   0.0   0.0   0.0
# 798  5.0  14.0  11.0   0.0   0.0   0.0   0.0
# 808  3.0  10.0  13.0   0.0   0.0   0.0   0.0
# 811  3.0  12.0  15.0   0.0   0.0   0.0   0.0
#
# [255 rows x 10 columns]

# %%
#mfCategory = ['Small Cap Fund', 'Mid Cap Fund']
mfCategory = ['Multi Cap Fund']
dfMF = dfMF[dfMF['Category Name'].isin(mfCategory)]

# %%
dfMF
# Out:
# Empty DataFrame
# Columns: [Scheme Name, Plan, Category Name, Crisil Rank, AuM (Cr), 1W, 1M, 3M, 6M, YTD, 1Y, 2Y, 3Y, 5Y, 10Y]
# Index: []

# %%
dfMF['Category Name'].unique()
# Out:
# array(['Index Funds/ETFs', 'Mid Cap Fund', 'Flexi Cap Fund',
#        'Large Cap Fund', 'Small Cap Fund', 'Large & Mid Cap Fund',
#        'Multi Cap Fund'], dtype=object)
